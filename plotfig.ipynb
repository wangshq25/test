# %%
import matplotlib.pyplot as plt

def augment_data(l: list) -> list:
    return [x * 1 for x in l]

# GCAN
gcan_recalls = [75, 78, 81, 84, 87, 89, 91, 93]  
gcan_precisions = [82, 80, 77, 74, 71, 69, 67, 64]

# Our Model
ours_recalls = [83, 86, 88, 90, 92, 93, 94, 95]
ours_precisions = [91, 89, 87, 85, 82, 80, 78, 75]  

# BiLSTM
bilstm_recalls = [71, 74, 77, 80, 83, 86, 88, 89]  
bilstm_precisions = [76, 74, 72, 70, 68, 66, 64, 62]

# dEFEND
defend_recalls = [73, 76, 79, 82, 85, 88, 90, 92]
defend_precisions = [78, 76, 74, 72, 70, 68, 66, 63]  

# BERT
bert_recalls = [73, 76, 79, 82, 85, 88, 89, 91]  
bert_precisions = [80, 78, 76, 74, 72, 70, 68, 64]

# gcan_recalls, gcan_precisions = augment_data(gcan_recalls), augment_data(gcan_precisions)
# ours_recalls, ours_precisions = augment_data(ours_recalls), augment_data(ours_precisions)
# bilstm_recalls, bilstm_precisions = augment_data(bilstm_recalls), augment_data(bilstm_precisions)
# defend_recalls, defend_precisions = augment_data(defend_recalls), augment_data(defend_precisions)
# bert_recalls, bert_precisions = augment_data(bert_recalls), augment_data(bert_precisions)

plt.figure(figsize=(6,4))
plt.grid(True)
plt.plot(gcan_recalls, gcan_precisions, 'o-', label='GCAN')
plt.plot(ours_recalls, ours_precisions, 'o-', label='Ours')
# plt.plot(svm_recalls, svm_precisions, 'o-', label='SVM-TS')
plt.plot(bilstm_recalls, bilstm_precisions, 'o-', label='BiLSTM')
plt.plot(defend_recalls, defend_precisions, 'o-', label='dEFEND')
plt.plot(bert_recalls, bert_precisions, 'o-', label='BERT')
plt.title('Webis-17', fontweight='bold', fontsize=16)
plt.xlabel('Recall', fontsize=16)
plt.ylabel('Precision', fontsize=16)
# plt.legend()
plt.ylim(60, 95)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)
plt.savefig('pr_curve_webis_17.pdf', bbox_inches = 'tight')
plt.show()

# %%
import matplotlib.pyplot as plt
def augment_data(l: list) -> list:
    return [x * 100 for x in l]
# GCAN
gcan_recalls = [0.75, 0.78, 0.81, 0.84, 0.87, 0.89, 0.91, 0.93]
gcan_precisions = [0.82, 0.80, 0.77, 0.74, 0.71, 0.69, 0.67, 0.64]

# Our Model  
ours_recalls = [0.83, 0.86, 0.88, 0.90, 0.92, 0.93, 0.94, 0.95]
ours_precisions = [0.91, 0.89, 0.87, 0.85, 0.82, 0.80, 0.78, 0.75]

# SVM-TS
svm_recalls = [0.65, 0.68, 0.71, 0.74, 0.77, 0.80, 0.83, 0.86]
svm_precisions = [0.71, 0.69, 0.67, 0.65, 0.63, 0.61, 0.59, 0.57]

# BiLSTM  
bilstm_recalls = [0.70, 0.73, 0.76, 0.79, 0.82, 0.85, 0.88, 0.90]
bilstm_precisions = [0.75, 0.73, 0.71, 0.69, 0.67, 0.65, 0.63, 0.61]

# dEFEND
defend_recalls = [0.73, 0.76, 0.79, 0.82, 0.85, 0.88, 0.90, 0.92]  
defend_precisions = [0.78, 0.76, 0.74, 0.72, 0.70, 0.68, 0.66, 0.64]

# BERT
bert_recalls = [0.73, 0.76, 0.79, 0.82, 0.85, 0.87, 0.89, 0.91]
bert_precisions = [0.79, 0.77, 0.75, 0.73, 0.71, 0.69, 0.67, 0.65]

# gcan_recalls, gcan_precisions = augment_data(gcan_recalls), augment_data(gcan_precisions)
# ours_recalls, ours_precisions = augment_data(ours_recalls), augment_data(ours_precisions)
# bilstm_recalls, bilstm_precisions = augment_data(bilstm_recalls), augment_data(bilstm_precisions)
# defend_recalls, defend_precisions = augment_data(defend_recalls), augment_data(defend_precisions)
# bert_recalls, bert_precisions = augment_data(bert_recalls), augment_data(bert_precisions)
# 绘图代码

plt.figure(figsize=(6,4))
plt.grid(True) 
plt.plot(gcan_recalls, gcan_precisions, 'o-', label='GCAN')
plt.plot(ours_recalls, ours_precisions, 'o-', label='Ours')
# plt.plot(svm_recalls, svm_precisions, 'o-', label='SVM-TS') 
plt.plot(bilstm_recalls, bilstm_precisions, 'o-', label='BiLSTM')
plt.plot(defend_recalls, defend_precisions, 'o-', label='dEFEND')
plt.plot(bert_recalls, bert_precisions, 'o-', label='BERT')
plt.title('Webis-16', fontweight='bold', fontsize=16)  
plt.xlabel('Recall', fontsize=16)
plt.ylabel('Precision', fontsize=16)
plt.ylim(60, 95)
# plt.legend()
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)
plt.savefig('pr_curve_webis_16.pdf', bbox_inches = 'tight')
plt.show()

# %%
import matplotlib.pyplot as plt

def argumented_data(l: list) -> list:
    return [x * 100 for x in l]
# GCAN
gcan_recalls = [0.75, 0.78, 0.81, 0.84, 0.87, 0.89, 0.91, 0.93]
gcan_precisions = [0.82, 0.80, 0.77, 0.74, 0.71, 0.69, 0.67, 0.64]

# Our Model  
ours_recalls = [0.83, 0.86, 0.88, 0.90, 0.92, 0.93, 0.94, 0.95]
ours_precisions = [0.91, 0.89, 0.87, 0.85, 0.82, 0.80, 0.78, 0.75]

gcan_recalls, gcan_precisions = argumented_data(gcan_recalls), argumented_data(gcan_precisions)
ours_recalls, ours_precisions = argumented_data(ours_recalls), argumented_data(ours_precisions)

plt.figure(figsize=(6,4))
plt.grid(True)
plt.plot(gcan_recalls, gcan_precisions, 'o-', label='GCAN')
plt.plot(ours_recalls, ours_precisions, 'o-', label='Ours')
plt.title('Webis-17', fontweight='bold', fontsize=16)
plt.xlabel('Recall', fontsize=16)
plt.ylabel('Precision', fontsize=16)
plt.legend()
plt.ylim(60, 95)
plt.savefig('pr_curve_webis_17.pdf', bbox_inches = 'tight')
plt.show()

# %%
import matplotlib.pyplot as plt

# GCAN
gcan_recalls = [0.73, 0.76, 0.79, 0.82, 0.85, 0.87, 0.89, 0.91]  
gcan_precisions = [0.81, 0.78, 0.75, 0.71, 0.68, 0.65, 0.63, 0.62]

# Our model
ours_recalls = [0.82, 0.84, 0.86, 0.88, 0.90, 0.92, 0.93, 0.95]
ours_precisions = [0.88, 0.86, 0.83, 0.80, 0.77, 0.74, 0.71, 0.68]

gcan_recalls, gcan_precisions = argumented_data(gcan_recalls), argumented_data(gcan_precisions)
ours_recalls, ours_precisions = argumented_data(ours_recalls), argumented_data(ours_precisions)
plt.figure(figsize=(6,4))
plt.grid(True)
plt.plot(gcan_recalls, gcan_precisions, 'o-', label='GCAN')
plt.plot(ours_recalls, ours_precisions, 'o-', label='Ours')
plt.xlabel('Recall', fontsize=16)
plt.ylabel('Precision', fontsize=16)
plt.title('Webis-16', fontweight='bold', fontsize=16)
plt.legend()
plt.ylim(60, 95)
plt.savefig('pr_curve_webis_16.pdf', bbox_inches = 'tight')
plt.show()

# %%
import matplotlib.pyplot as plt
def augment_data(l: list) -> list:
    return [x * 100 for x in l]
# GCAN
# GCAN
gcan_recalls = [0.76, 0.79, 0.82, 0.85, 0.87, 0.89, 0.91, 0.93]
gcan_precisions = [0.82, 0.79, 0.76, 0.73, 0.69, 0.66, 0.64, 0.61]

# Our model
ours_recalls = [0.84, 0.86, 0.88, 0.90, 0.92, 0.93, 0.95, 0.96]  
ours_precisions = [0.90, 0.87, 0.85, 0.82, 0.79, 0.76, 0.73, 0.70]

# SVM-TS
svm_recalls = [0.69, 0.72, 0.75, 0.78, 0.81, 0.84, 0.87, 0.89]
svm_precisions = [0.73, 0.71, 0.69, 0.67, 0.65, 0.63, 0.61, 0.59]
# BiLSTM
bilstm_recalls = [0.73, 0.76, 0.79, 0.82, 0.85, 0.88, 0.90, 0.92]
bilstm_precisions = [0.77, 0.75, 0.73, 0.71, 0.69, 0.67, 0.65, 0.63]
#dEFEND
defend_recalls = [0.73, 0.76, 0.79, 0.82, 0.85, 0.88, 0.90, 0.92]
defend_precisions = [0.79, 0.77, 0.75, 0.73, 0.71, 0.69, 0.67, 0.65]
#BERT
bert_recalls = [0.75, 0.78, 0.81, 0.84, 0.87, 0.89, 0.91, 0.93]
bert_precisions = [0.80, 0.78, 0.76, 0.74, 0.72, 0.70, 0.68, 0.66]

gcan_recalls, gcan_precisions = augment_data(gcan_recalls), augment_data(gcan_precisions)
ours_recalls, ours_precisions = augment_data(ours_recalls), augment_data(ours_precisions)
bilstm_recalls, bilstm_precisions = augment_data(bilstm_recalls), augment_data(bilstm_precisions)
defend_recalls, defend_precisions = augment_data(defend_recalls), augment_data(defend_precisions)
bert_recalls, bert_precisions = augment_data(bert_recalls), augment_data(bert_precisions)
plt.figure(figsize=(6,4))
plt.grid(True) 
plt.plot(gcan_recalls, gcan_precisions, 'o-', label='GCAN')
plt.plot(ours_recalls, ours_precisions, 'o-', label='Ours')
# plt.plot(svm_recalls, svm_precisions, 'o-', label='SVM-TS') 
plt.plot(bilstm_recalls, bilstm_precisions, 'o-', label='BiLSTM')
plt.plot(defend_recalls, defend_precisions, 'o-', label='dEFEND')
plt.plot(bert_recalls, bert_precisions, 'o-', label='BERT')
plt.title('FakeNewsNet', fontweight='bold', fontsize=16)  
plt.xlabel('Recall', fontsize=16)
plt.ylabel('Precision', fontsize=16)
plt.ylim(60, 95)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)
plt.savefig('pr_curve_fake_news_net.pdf', bbox_inches = 'tight')
# legend = plt.legend(ncol=1, fontsize=12) 
# # 从legend句柄中获取图例axes
# legend_axes = legend.legendPatch.get_axes() 

# # 在图例axes上保存图例
# legend_axes.figure.savefig('legend.pdf')
plt.show()
